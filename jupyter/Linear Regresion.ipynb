# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("cost_revenue_clean.csv")

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
x,y = DataFrame(data,columns=["production_budget_usd"]), DataFrame(data, columns=["worldwide_gross_usd"])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y, alpha=0.3)
plt.title("Filr Cost vs Total Revenue")
plt.xlabel("Production Budget $")
plt.ylabel("Worldwide Gross $")
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
regression = LinearRegression()

# %%
regression.fit(x,y)
# Out:
# LinearRegression()

# %%
regression.coef_ #Slope coefficient: theta_1. This is letting us know that, for every dollar spent on budget
#we are going to get 3.11 dollars on revenue
# Out:
# array([[3.11150918]])

# %%
#Intercept
regression.intercept_#A movie with a budget of 0, we would lose 7 million. this one has an error. not a very
#reliable model
# Out:
# array([-7236192.72913958])

# %%
#Plotting the slope
plt.figure(figsize=(10,6))
plt.scatter(x,y, alpha=0.3)
plt.plot(x.values, regression.predict(x.values), color="red", linewidth=4)
plt.title("Film Cost vs Total Revenue")
plt.xlabel("Production Budget $")
plt.ylabel("Worldwide Gross $")
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()
# Out:
# /home/antonio/Repositorios/private/dataScienceAndML/jupyter/jupyterenv/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#To measure how good our model is, we use r^2
regression.score(x,y)
# Out:
# 0.5496485356985729
